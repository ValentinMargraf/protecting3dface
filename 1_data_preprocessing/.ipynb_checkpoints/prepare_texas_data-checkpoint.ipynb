# %% [markdown]
# # DEPTH DATA AUGMENTATION

# %%
import os
from PIL import Image
import numpy as np
import tensorflow as tf
from scipy import ndimage, misc
from mtcnn.mtcnn import MTCNN
from matplotlib import pyplot as plt
from pathlib import Path, PurePath

# %%
import sys
sys.path.append('../2_neural_net_training/')
from data_augmentation_utils import *
from models import *

# %% [markdown]
# ## input portrait & range, portrait is used for face detection

# %%
#import dlib
import cv2



# extract a single face from a given photograph
def extract_face(fn_portrait, fn_range, i,required_size=(224, 224)):
    # load image from file
    portrait_ = cv2.imread(fn_portrait)   
    portrait_ = cv2.cvtColor(portrait_, cv2.COLOR_BGR2RGB)
    #portrait_ = cv2.resize(portrait_,(720,960))
    range_ = cv2.imread(fn_range)
    #range_= cv2.resize(range_,(720,960))
    # create the detector, using default weights
    detector = MTCNN()
    # detect faces in the image
    results = detector.detect_faces(portrait_)
    # extract the bounding box from the first face
    x1, y1, width, height = results[0]['box']
    x2, y2 = x1 + width, y1 + height
    # extract the face
    face = range_[y1:y2, x1:x2]
    # resize to the model size
    face_array = cv2.resize(face,(required_size))
    #print(i)
    return face_array
    
def load_depth_faces(data_path_portrait, data_path_range, size=(224,224)):
    """
    loading the data
    
    input: 
        data_path: path to the data
    
    output:
        arrays of the images
  
    """
    ROOT = "../DATA_depth_images_raw/opensource_DATA/texas/PreprocessedImages"
    n = len(data_path_range)
    #print(n)
    return np.asarray([extract_face(ROOT + '/' + data_path_portrait[i], ROOT + '/' + data_path_range[i], i,size) for i in range(n)])

# %% [markdown]
# ## LOAD DATA, separate range and portrait

# %%
ROOT = "../DATA_depth_images_raw/opensource_DATA/texas/PreprocessedImages"
files = sorted(os.listdir(ROOT))

# %%
filenames_range=[]
filenames_portrait=[]
for i in range(len(files)):
    p=PurePath(files[i])
    name=p.stem
    #print(p)
    if str(name)[-5:] == "Range":
        filenames_range.append(name+p.suffix)
    else: 
        filenames_portrait.append(name+p.suffix)
print(filenames_portrait[1149])
print(str(filenames_portrait[:3]))
print(len(filenames_portrait))
# Out:
# Thumbs.db
# ['Clean_0001_001_20050913115022_Portrait.png', 'Clean_0002_002_20050913094354_Portrait.png', 'Clean_0003_003_20050913094955_Portrait.png']
# 1150

# %%
print(len(filenames_range))
# Out:
# 1149

# %%
data = load_depth_faces(filenames_portrait,filenames_range)
# Out:
# 2023-03-23 16:18:12.224917: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...
# 1/1 [==============================] - 0s 127ms/step
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb28ffa4820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
# 1/1 [==============================] - 0s 165ms/step
# ...

# %% [markdown]
# ## i added many lines np.save s.t. if certain cells fail, you dont have to repeat all other cells, but can start from the next np.load

# %%
np.save("DATA_npy/texas_data",data)

# %%
data=np.load("DATA_npy/texas_data.npy")

# %%
print(data.shape)
# Out:
# (1149, 224, 224, 3)

# %%
fig = plt.figure(figsize=(20, 20))
rows = 3
columns = 3
j=10


for i in range(rows*columns):
    fig.add_subplot(rows, columns, i+1)
    plt.imshow(data[j+i])
plt.savefig('texas.png',facecolor='white', transparent=False)

# %% [markdown]
# ## generate labels by extracting information from the csv file

# %%
import csv
labels = []
with open('texas_info.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in spamreader:
        label=row[0][-29:-26]
        label=label.replace("g","")
        label=label.replace(",","")
        label=int(label)
        labels.append(label)
print(labels)
# Out:
# [1, 2, 3, 3, 4, 4, 5, 5, 6, 7, 8, 9, 9, 10, 10, 11, 11, 12, 12, 13, 13, 14, 15, 15, 16, 16, 17, 17, 18, 18, 19, 19, 20, 20, 21, 21, 22, 22, 23, 23, 24, 24, 25, 25, 25, 26, 26, 27, 27, 28, 28, 29, 29, 30, 30, 31, 31, 32, 32, 33, 33, 34, 34, 35, 36, 36, 37, 37, 38, 38, 39, 39, 40, 40, 41, 41, 42, 42, 43, 43, 44, 44, 45, 45, 46, 46, 47, 47, 48, 48, 49, 49, 50, 50, 51, 51, 52, 52, 53, 53, 54, 54, 90, 55, 55, 56, 56, 57, 57, 58, 58, 59, 59, 60, 60, 61, 61, 62, 62, 63, 63, 64, 64, 65, 65, 66, 66, 67, 67, 68, 68, 69, 70, 70, 71, 71, 72, 72, 73, 73, 74, 74, 74, 75, 75, 76, 77, 77, 78, 78, 79, 79, 80, 80, 81, 81, 82, 82, 83, 83, 84, 84, 85, 86, 86, 87, 88, 88, 89, 89, 90, 90, 91, 91, 92, 92, 93, 93, 94, 94, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 95, 96, 96, 96, 96, 96, 96, 96, 96
# ...

# %%
labels=np.asarray(labels)
np.save("DATA_npy/labels_texas",labels)

# %%
labels=np.load("DATA_npy/labels_texas.npy")
print((labels[:20]))
# Out:
# [ 1  2  3  3  4  4  5  5  6  7  8  9  9 10 10 11 11 12 12 13]

# %%
fig = plt.figure(figsize=(15, 15))
rows = 3
columns = 3



for i in range(rows*columns):
    fig.add_subplot(rows, columns, i+1)
    plt.imshow(data[i+10])
    plt.title("label: "+ str(labels[i+10]))
plt.savefig('texas.png',facecolor='white', transparent=False)

# %% [markdown]
# ## generate train/test splits. we only take identities from which we have at least 18 images (this is exactly the number of images per BDR identity. so we force balanced datasets)

# %%
unseen_inds = []
test_inds = []
train_inds = []
#print(num_persons)

# pay attention here:
# it may happen that Labels is not in the form np.arange(0,labels.max())

for j in set(labels):
    indices = np.argwhere(labels==j).flatten()
    occ=len(indices)
    if occ <= 17:
        for m in range(occ):
            unseen_inds.append(indices[m])
        #unseen_inds.append(indices)
    if occ > 17:
        #half=occ//2
        half=9
        #print("HALF",half)
        for i in range(9):
            #print("I",i)
            train_inds.append(indices[i])
        for k in range(9,18):
            #print("K",k)
            test_inds.append(indices[k])
    print("label",j,"occurs",occ,"times")

train_inds=np.asarray(train_inds)
test_inds=np.asarray(test_inds)
unseen_inds=np.asarray(unseen_inds)

#print(np.asarray(test_inds).flatten())
# since they are weird nested lists
unseen_inds = np.asarray([x for list in unseen_inds for x in list])
#test_inds = np.asarray([x for list in test_inds for x in list])
# Out:
# label 1 occurs 1 times
# label 2 occurs 1 times
# label 3 occurs 2 times
# label 4 occurs 2 times
# label 5 occurs 2 times
# label 6 occurs 1 times
# label 7 occurs 1 times
# label 8 occurs 1 times
# label 9 occurs 2 times
# label 10 occurs 2 times
# label 11 occurs 2 times
# label 12 occurs 2 times
# label 13 occurs 2 times
# label 14 occurs 1 times
# label 15 occurs 2 times
# label 16 occurs 2 times
# label 17 occurs 2 times
# label 18 occurs 2 times
# label 19 occurs 2 times
# label 20 occurs 2 times
# label 21 occurs 2 times
# label 22 occurs 2 times
# label 23 occurs 2 times
# label 24 occurs 2 times
# label 25 occurs 3 times
# label 26 occurs 2 times
# label 27 occurs 2 times
# label 28 occurs 2 times
# label 29 occurs 2 times
# label 30 occurs 2 times
# label 31 occurs 2 times
# label 32 occurs 2 times
# label 33 occurs 2 times
# label 34 occurs 2 times
# label 35 occurs 1 times
# label 36 occurs 2 times
# label 37 occurs 2 times
# label 38 occurs 2 times
# ...

# %%
print(train_inds)
print(test_inds)
print(unseen_inds)
# Out:
# [ 180  181  182  183  184  185  186  187  188  245  246  247  248  249
#   250  251  252  253  332  333  334  335  336  337  338  339  340  357
#   358  359  360  361  362  363  364  365  384  385  386  387  388  389
#   390  391  392  470  471  472  473  474  475  476  477  478  538  539
#   540  541  542  543  544  545  546  583  584  585  586  587  588  589
#   590  591  646  647  648  649  650  651  652  653  654  644  645  672
#   673  674  675  676  677  678  694  695  696  697  698  699  700  701
#   702  767  768  769  770  771  772  773  774  775  852  853  854  855
#   856  857  858  859  860  879  880  881  882  883  884  885  886  887
#   906  907  908  909  910  911  912  913  914  938  939  940  941  942
#   943  944  945  946  984  985  986  987  988  989  990  991  992 1073
#  1074 1075 1076 1077 1078 1079 1080 1081]
# [ 189  190  191  192  193  194  195  196  197  254  255  256  257  258
#   259  260  261  262  341  342  343  344  345  346  347  348  349  366
# ...

# %%
from keras_vggface.utils import preprocess_input as preprocess

train_texas=data[train_inds]
test_texas=data[test_inds]
unseen_texas=data[unseen_inds]




labels_texas_train=labels[train_inds]
labels_texas_test=labels[test_inds]
labels_texas_unseen=labels[unseen_inds]

np.save("DATA_npy/labels_texas_train.npy",labels_texas_train)
np.save("DATA_npy/labels_texas_test.npy",labels_texas_test)
np.save("DATA_npy/labels_texas_unseen.npy",labels_texas_unseen)


print(train_texas.shape)
print(test_texas.shape)
print(unseen_texas.shape)
# Out:
# (162, 224, 224, 3)
# (162, 224, 224, 3)
# (186, 224, 224, 3)

# %%
fig = plt.figure(figsize=(15, 15))
rows = 3
columns = 3



for i in range(rows*columns):
    fig.add_subplot(rows, columns, i+1)
    plt.imshow(train_texas[i+45])
    plt.title("label: "+ str(labels_texas_train[i+45]))

# %% [markdown]
# # save data as npy

# %% [markdown]
# ### train and test data with labels, use preprocess vgg func

# %%
from keras_vggface.utils import preprocess_input as preprocess


train_texas = np.asarray(train_texas, 'float32')
train_texas_vgg = preprocess(train_texas, version=2)
np.save('DATA_npy/train_texas_vgg',train_texas_vgg)

test_texas = np.asarray(test_texas, 'float32')
test_texas_vgg = preprocess(test_texas, version=2)
np.save('DATA_npy/test_texas_vgg',test_texas_vgg)

unseen_texas = np.asarray(unseen_texas, 'float32')
unseen_texas_vgg = preprocess(unseen_texas, version=2)
np.save('DATA_npy/unseen_texas_vgg',unseen_texas_vgg)

# %% [markdown]
# # DATA AUGMENTATION (funcs inside /2_neural_net_training/data_augmentation_utils.py)

# %%
faces_train_vgg = np.load('DATA_npy/train_texas_vgg.npy')
labels_train_vgg = np.load('DATA_npy/labels_texas_train.npy')
labels_train=labels_train_vgg

# %%
print(faces_train_vgg.shape)
print(labels_train.shape)
# Out:
# (162, 224, 224, 3)
# (162,)

# %% [markdown]
# ## FLIP IMAGES

# %%
faces_train_vgg_flip, labels_flip_vgg = flip(faces_train_vgg, labels_train_vgg) 

print("flipped")
print(faces_train_vgg_flip.shape)
print(labels_flip_vgg.shape)
# Out:
# flipped
# (324, 224, 224, 3)
# (324,)

# %%
fig = plt.figure(figsize=(10, 7))
rows = 3
columns = 3 



for i in range(rows*columns):
    fig.add_subplot(rows, columns, i+1)
    plt.imshow(faces_train_vgg_flip[i])    
    plt.title("label: "+ str(labels_flip_vgg[i]))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %% [markdown]
# ## rotate images

# %%
faces_train_vgg_rot, labels_rot_vgg = rotate(faces_train_vgg_flip, labels_flip_vgg, max_degree=10, how_often=2) 
print("rotated")
# Out:
# rotated

# %%
print(faces_train_vgg_rot.shape)
# Out:
# (972, 224, 224, 3)

# %%
np.save('DATA_npy/face_rot_flip_vgg_texas',faces_train_vgg_rot)
np.save('DATA_npy/labels_rot_flip_vgg_texas',labels_rot_vgg)

# %%
faces_train_vgg_rot=np.load('DATA_npy/face_rot_flip_vgg_texas.npy')
labels_rot_vgg=np.load('DATA_npy/labels_rot_flip_vgg_texas.npy')

# %%
print(faces_train_vgg_rot.shape)
print(labels_rot_vgg.shape)
# Out:
# (972, 224, 224, 3)
# (972,)

# %%
print(labels_rot_vgg[:30])
# Out:
# [95 95 95 95 95 95 95 95 95 96 96 96 96 96 96 96 96 96 97 97 97 97 97 97
#  97 97 97 99 99 99]

# %% [markdown]
# ## WARP images

# %%
faces_train_vgg_warped, labels_vgg_warped = warp(faces_train_vgg_rot, labels_rot_vgg,  how_often=2)
# Out:
# 0
# 1000

# %%
faces_train_vgg_noise, labels_vgg_noise = gaussian_noise(faces_train_vgg_rot, labels_rot_vgg,  how_often=1) 
print("added_noise")
# Out:
# added_noise

# %%
faces_train_vgg_all = np.concatenate((faces_train_vgg_noise,faces_train_vgg_rot))
labels_train_vgg_all = np.concatenate((labels_vgg_noise,labels_rot_vgg))

# %%
np.save('DATA_npy/TEXAS_AUGMENTED_faces',faces_train_vgg_all)
np.save('DATA_npy/TEXAS_AUGMENTED_labels',labels_train_vgg_all)
